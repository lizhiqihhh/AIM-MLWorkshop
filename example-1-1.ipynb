# %% [markdown]
# # Introduction
#
# >In this assignment,you will learn basics for using git to manage your project
#
#
# This notebook comprises the following sections:
# * [1.Local git set up](#1.Local-git-set-up)
# * [2.Create a local repo](#2.Create-a-local-repo)
# * [3.Create a remote repo](#3.Create-a-remote-repo)
#     * [3.1 Sync with the remote repo](#3.1-Sync-with-the-remote-repo)

# %% [markdown]
# # 1.Local git set up

# %% [markdown]
# <font color=balck size=4 face=brill>(1) set up your account and email</font>

# %%
git config --global user.name 'your_name'
git config --global user.email 'your_email'

# %% [markdown]
# <font color=balck size=4 face=brill>(2) generate ssh key</font>

# %%
ssh-keygen -t rsa -C 'your_email'

# %% [markdown]
# <font color=balck size=4 face=brill>(3)Add the generated public key in file <mark style=background-color:red>id_rsa.pub</mark>
# （copy contents）to the setting of your github ( SSH AND GPG KEY / SSH keys)</font>

# %% [markdown]
# <font color=balck size=4 face=brill>Double check, type the below command in git bash, if it shows successfully authenticated, done!</font>

# %%
ssh git@github.com

# %% [markdown]
# # 2. Create a local repo

# %% [markdown]
# * cd to the project path
# * git init
# * git add .
# * git commit -m
#
# * git fetch origin discover
# * git checkout discover

# %% [markdown]
# # 3. Create a remote repo
# >create a new repository in the github，copy the address of your repo：

# %% [markdown]
# **<font color=black size=4 >Your original repo</font>**: https://github.com/yourname/yourproject.git

# %% [markdown]
# ### 3.1 Sync with the remote repo

# %%
git remote add origin https://github.com/CongliYin/CSS.git

# %%
git push origin master

# %% [markdown]
# https://phoenixnap.com/kb/how-to-use-git

# %%
import matplotlib.pyplot as plt

#Plot a line graph
plt.plot([5, 15], label='Rice')
plt.plot([3, 6], label='Oil')
plt.plot([8.0010, 14.2], label='Wheat')
plt.plot([1.95412, 6.98547, 5.41411, 5.99, 7.9999], label='Coffee')

# Add labels and title
plt.title("Interactive Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
 
y1 = [12, 14, 15, 18, 19, 13, 15, 16]
y2 = [22, 24, 25, 28, 29, 23, 25, 26]
y3 = [32, 34, 35, 38, 39, 33, 35, 36]
y4 = [42, 44, 45, 48, 49, 43, 45, 46]
y5 = [52, 54, 55, 58, 59, 53, 55, 56]
 
 
# Plot lines with different marker sizes
plt.plot(y1, y2, label = 'Y1-Y2', lw=2, marker='s', ms=10) # square
plt.plot(y1, y3, label = 'Y1-Y3', lw=2, marker='^', ms=10) # triangle
plt.plot(y1, y4, label = 'Y1-Y4', lw=2, marker='o', ms=10) # circle
plt.plot(y1, y5, label = 'Y1-Y5', lw=2, marker='D', ms=10) # diamond
plt.plot(y2, y5, label = 'Y2-Y5', lw=2, marker='P', ms=10) # filled plus sign
 
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
 
 
fig = plt.figure()
ax = plt.axes(projection ='3d')

# %% [markdown]
# With the above syntax three -dimensional axes are enabled and data can be plotted in 3 dimensions. 3 dimension graph gives a dynamic approach and makes data more interactive. Like 2-D graphs, we can use different ways to represent 3-D graph. We can make a scatter plot, contour plot, surface plot, etc. Let’s have a look at different 3-D plots.

# %% [markdown]
# 3 dimension graph gives a dynamic approach and makes data more interactive. Like 2-D graphs, we can use different ways to represent 3-D graph. We can make a scatter plot, contour plot, surface plot, etc. Let’s have a look at different 3-D plots.

# %% [markdown]
# ### 3D dimensional line graph

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()
ax = plt.axes(projection='3d')
z = np.linspace(0, 1, 100)

y=z * np.sin(20 * z)
x= z * np.cos(20 * z)

ax.plot3D(x, y, z, 'darkorange')
ax.set_title('3D line plot')

plt.show()

# %% [markdown]
# ### 3D dimensional scatter graph

# %%
# importing mplot3d toolkits
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
 
fig = plt.figure()
 
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
 
# defining axes
z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)
c = x + y
ax.scatter(x, y, z, c = c)
 
# syntax for plotting
ax.set_title('3d Scatter plot geeks for geeks')
plt.show()

# %% [markdown]
# more types of 3D plot can be found in https://www.geeksforgeeks.org/three-dimensional-plotting-in-python-using-matplotlib/

# %%
import nltk
from nltk.corpus import webtext
from nltk.probability import FreqDist
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import os

nltk.download('webtext')
wt_words = webtext.words('testing.txt')  # Sample data
data_analysis = nltk.FreqDist(wt_words)

filter_words = dict([(m, n) for m, n in data_analysis.items() if len(m) > 3])

wcloud = WordCloud().generate_from_frequencies(filter_words)

# Plotting the wordcloud
plt.imshow(wcloud, interpolation="bilinear")

plt.axis("off")
(-0.5, 499.5, 299.5, -0.5)
plt.show()

# %%
# !pip install nltk
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621

# %%
pip install wordcloud
# Out:
# 4769.94s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
#   Using cached wordcloud-1.8.2.2.tar.gz (220 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wordcloud: filename=wordcloud-1.8.2.2-cp310-cp310-macosx_12_0_arm64.whl size=154550 sha256=a7f01f16925e429b393d45e9672c0909fca0bf07e8b3e9616117c6c3e1066a74
#   Stored in directory: /Users/zhiqi22/Library/Caches/pip/wheels/30/52/73/36458d38e3c533678a3043949ad72658025d8e89d942439d49
# Successfully built wordcloud
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install numpy

# %%
import sys
sys.path

# %%
# !type -a pip

# %%
# !type -a python

# %%
# !conda env list

# %% [markdown]
# ## Learn Pytorch the easy way

# %% [markdown]
# ### Introduction to Tensors

# %% [markdown]
# Pytorch tensors are created using torch.Tensor
# >Understand that a tensor can represent any shape of data
# - scaler: a single number
# - vector: a numbr with direction
# - matrix: a 2-dimensional array of numbers
# - tensor: an n-dimensional array of numbers

# %%
pip install torch

# %%
import torch
scaler = torch.tensor(8)

# %%
scaler
scaler.ndim

# %%
vector = torch.tensor([7,7])

# %%
vector

# %%
vector.ndim

# %%
vector.shape

# %%
#Matrix
matrix = torch.tensor([[7,8],[4,5]])
matrix

# %%
matrix.shape

# %%
one_to_ten = torch.arange(start=1, end=11, step=1)
ten_zeros = torch.zeros_like(input=one_to_ten)

# %%
ten_zeros

# %% [markdown]
# ### Tensor datatypes
# **Note** Tensor datatypes is one of the 3 big issues with PyTorch & Deep Learning
# 1. Tensors not right datatype
# 2. Tensors not right shape
# 3. Tensors not on the right device (cpu/gpu/cuda)

# %%
float_32_tensor = torch.tensor([12.0, 16.0, 19.0], 
                               dtype=torch.float32, 
                               device=None, 
                               requires_grad=False)

# %%
float_32_tensor.dtype

# %% [markdown]
# If you want to know more about the datatype that tensor support, you can go to the torch official document

# %%
int32_tensor = torch.tensor([3,6,9], dtype=torch.int32)
int32_tensor

# %%
float_32_tensor * int32_tensor # set the right datatype

# %%
int_32_tensor = torch.tensor([10,12,16], dtype=torch.long)
int_32_tensor

# %%
float_32_tensor * int_32_tensor

# %% [markdown]
# ### Getting information from tensors
# 1. Tensors not right datatype - to get the datatype from a tensor, can use tensor.dtype
# 2. Tensors not right shape - tensor.shape
# 3. Tensors not on the right device (cpu/gpu/cuda) - tensor.device

# %%
# create a tensor
rand_t = torch.rand(3,4)
rand_t

# %%
rand_t.dtype

# %%
rand_t.device

# %%
rand_t.shape

# %% [markdown]
# ### Tensor Device
# Pytorch tensors can be stored on two devices, namely CPU & GPU. When no device is specified, Pytorch will store tensors on CPU by default; if you want to transfer tensors to GPU, you need to specify tensors to transfer to GPU device.

# %%
import torch
torch.randn(3,3, device="cuda:0")       # create a tensor that is stored on GPU 0

torch.randn(3,3, device="cuda:0").cpu() # switch from GPU to CPU storage

# %% [markdown]
# ### Manipulating tensors (tensor operations)
# Tensor operations include
# * Addition
# * Substraction
# * Multiplication (element-wise)
# * Division
# * Matrix Multiplication

# %%
tensor1 = torch.tensor([3,4,5])
tensor1+10 # or use a in-built function torch.add

# %%
tensor = tensor1*10

# %%
tensor1

# %%
tensor

# %%
tensor = tensor -10
tensor

# %%
# try a pytorch inbuilt functions
torch.mul(tensor, 10)

# %% [markdown]
# **Introduction to matrix multiplication**: https://www.mathsisfun.com/algebra/matrix-multiplying.html

# %% [markdown]
# - Two Main ways for matric multiplication
# 1. Element-wise
# 2. Matrix-mul == dot product

# %%
# Element-wise
tensor*tensor1

# %%
# Matrix multiplication
torch.matmul(tensor, tensor)

# %% [markdown]
# ### Finding the max, min, mean, and sum

# %%
x = torch.arange(0,100,10)

# %%
x

# %%
torch.min(x), x.min

# %%
torch.max(x)

# %%
torch.mean(x) # not the right type!
#note! the torch.mean() function requires a tensor of float32 datatype to work

# %%
x.dtype

# %%
torch.mean(x.type(torch.float32))

# %%
torch.sum(x)

# %% [markdown]
# ### reshapeing/reviewing/stacking
# * reshaping - reshape the tensor into a defined shape
# * reviewing - return a view of an input tensor of certain shape but keep
#   the same memory as the original tensor
# * stacking - combine multiple tensors on top of each other (vstack) or side by side
# * squeeze - remove all '1' dimensions from a tensor
# * unsqueeze - add a '1' dimension to a target tensor
# * permute - return a view of the input with dimensions swapped in a certain way

# %%
y = torch.arange(1., 10.)
y, y.shape

# %%
y_reshaped = y.reshape(1,9)

# %%
y_reshaped, y_reshaped.shape

# %%
#change the view, the view of a tensor shares the same memory as the original tensor
z = y.view(1,9)
z,z.shape

# %%
z[:,7] = 5
z,y

# %%
y_stacked = torch.stack([y,y,y,y],dim=0) #dim1
y_stacked

# %% [markdown]
# ### practice other variants of stack, e.g., hstack, vstack

# %% [markdown]
# if you are stacked, go to the documentation, look something up,
# print it out like this quite cumbersome but this is to give us a good
# explanation for what's happening

# %% [markdown]
# ## Indexing (selecting data from tensors)
# indexing with Pytorch is similar to indexing with numpy

# %%
import torch
x = torch.arange(1, 10).reshape(1,3,3)

# %%
x, x.shape

# %%
x[0]

# %%
x[0,0]

# %%
x[0,:,1]

# %%
x[:,:,0]

# %%
x = torch.tensor([[[0,5,4],[2,7,3]],[[4,9,2],[6,11,1]]])

# %%
x

# %%
x.shape

# %%
x[0,1,0]

# %%
torch.swapaxes(x, 0, 2)

# %%
torch.swapaxes(x, 1, 2)

# %% [markdown]
# ## PyTorch tensors & Numpy
#
# > Numpy is a popular scientific Python numerical computing library
# And because of this, Pytorch has functionality to interact with it.
#
# * Data in Numpy, want in PyTorch tensor -> torcg.from_numpy(ndarray)

# %%
import numpy as np
import torch
array = np.arange(1.0, 8.0)
tensor = torch.from_numpy(array)

# %%
array,tensor

# %%
array.dtype

# %%
torch.arange(1.0, 8.0).dtype

# %%
import numpy as np
abs = torch.tensor([1, 2], dtype=torch.float64)
angle = torch.tensor([np.pi / 2, 5 * np.pi / 4], dtype=torch.float64)
z = torch.polar(abs, angle)
z

# %%
abs

# %%
angle

# %%
np.pi

# %%
torch.acos(angle)

# %%
polar = torch.randn(4,3,2)

r = polar[:,:,0]
theta = polar[:,:,1]

x = r * torch.cos(theta)
y = r * torch.sin(theta)

cartesian = torch.stack([x,y], axis = -1)

# %%
r

# %%
polar

# %%
cartesian
